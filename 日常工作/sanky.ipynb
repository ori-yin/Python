# %%
from pyecharts import options as opts    # 导入pyecharts包
from pyecharts.charts import Sankey    # 导入桑基图
import pandas as pd    # 导入pandas

# %%
路径 = 'D:\ori-learn\充值2.csv'    # 确定文件路径
data = pd.read_csv(路径,encoding='GBK')    # pandas读取文件下的sheet

# %%
data
# Out:
#           首冲   二次充值   三次充值   四次充值      UID
# 0      个人非终身  无续费-2  无续费-3  无续费-4  3529429
# 1      个人非终身  无续费-2  无续费-3  无续费-4  3529417
# 2      个人非终身  无续费-2  无续费-3  无续费-4   151784
# 3       个人终身  无续费-2  无续费-3  无续费-4  3528904
# 4      PPT会员  无续费-2  无续费-3  无续费-4  3528736
# ...      ...    ...    ...    ...      ...
# 26466  个人非终身  无续费-2  无续费-3  无续费-4      531
# 26467  个人非终身  无续费-2  无续费-3  无续费-4      496
# 26468  个人非终身  无续费-2  无续费-3  无续费-4      408
# 26469  个人非终身  无续费-2  无续费-3  无续费-4      403
# 26470  个人非终身  无续费-2  无续费-3  无续费-4      320
#
# [26471 rows x 5 columns]

# %%
# 生成：父类 → 子类 → 值
lis = data.columns.tolist()[:-1]    # 取所有列名创建列表，除需要 统计计算 的数据
lis1 = lis[:-1]    # 取父类至子类最后一列的前一个
lis2 = lis[1:]    # 取除父类外的所有子类

# %%
data1 = pd.DataFrame()
for i in zip(lis1,lis2):    # zip可将两个列表上下进行连接***
    透视表 = data.pivot_table('UID',index=list(i),aggfunc='count').reset_index()
    # 透视表pivot_table(需要聚合运算的数值，index=索引标签，aggfunc=聚合方式)
    透视表.columns=[0,1,2]    # 透视表的列重命名
    data1 = data1.append(透视表)    # 重命名列后表叠加在一起|
# Out:
# C:\Users\HCKJ\AppData\Local\Temp\ipykernel_11280\2844368801.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = data1.append(透视表)    # 重命名列后表叠加在一起|
# C:\Users\HCKJ\AppData\Local\Temp\ipykernel_11280\2844368801.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = data1.append(透视表)    # 重命名列后表叠加在一起|
# C:\Users\HCKJ\AppData\Local\Temp\ipykernel_11280\2844368801.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1 = data1.append(透视表)    # 重命名列后表叠加在一起|

# %%
# 生成节点数据，注意！！！非常重要，不同列之间不能有相同的节点名称！！！
节点 = []
节点.append({'name':'个人非终身'})    # 先添加第零列的父节点，所有父节点必须填
节点.append({'name':'个人终身'})    # 先添加第零列的父节点，所有父节点必须填
节点.append({'name':'个人商用'})    # 先添加第零列的父节点，所有父节点必须填
节点.append({'name':'PPT会员'})    # 先添加第零列的父节点，所有父节点必须填
节点.append({'name':'视频会员'})    # 先添加第零列的父节点，所有父节点必须填
节点.append({'name':'企业会员'})    # 先添加第零列的父节点，所有父节点必须填


for i in data1[1].unique():    # 添加其他节点
    dic = {}    # 创建空字典
    dic['name'] = i    # 字典名字与节点相关联
    节点.append(dic)    # append用于给列表末尾不断加新的数据

# %%
# 生成连接数据
连接 = []
for i in data1.values:    # 遍历表中的数据
    dic = {}    # 创建空字典
    dic['source'] = i[0]    # 桑基图的源头 = 第零列
    dic['target'] = i[1]    # 流量路径 = 第一列
    dic['value'] = i[2]    # 具体数值 = 第二列
    连接.append(dic)    # append用于给列表末尾不断加新的数据

# %%
# 开始画图啦！
桑基图 = (
    Sankey(init_opts=opts.InitOpts(width="1920px", height="1080px",theme='light',page_title= "历史充值（不含近90天充值）"))
    # width设置宽度，height设置高度
    # theme主题风格：light,dark,chalk,essos,infographic,macarons,shine,walden,westeros
    .add(
        "",
        nodes=节点,
        links=连接,
        orient='horizontal',    # 'horizontal'=水平，'vertical'=垂直
        linestyle_opt=opts.LineStyleOpts(opacity=0.4, curve=0.5, color="source"),
        # opacity=不透明度，curve=弯曲度
        label_opts=opts.LabelOpts(position="right"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title='历史充值（不含近90天充值）'))    # 标题名称
) 
桑基图.render('D:\ori-learn\历史充值.html')    # 保存到本地
# Out:
# 'D:\\ori-learn\\历史充值.html'

# %%
桑基图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="87baf322b1a54cb1a7e822c860a6ad1b" style="width:1920px; height:1080px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_87baf322b1a54cb1a7e822c860a6ad1b = echarts.init(
#                     document.getElementById('87baf322b1a54cb1a7e822c860a6ad1b'), 'light', {renderer: 'canvas'});
#                 var option_87baf322b1a54cb1a7e822c860a6ad1b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u6708"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u5e74"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u5b63"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u5e74"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u5b63"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u6708"
#                 },
#                 {
#                     "name": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014"
#                 },
#                 {
#                     "name": "\u4f01\u4e1aVIP-\u5168\u7528\u9014"
#                 },
#                 {
#                     "name": "\u672a\u5145\u503c-2"
#                 },
#                 {
#                     "name": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014-2"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u5e74-2"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u5e74-2"
#                 },
#                 {
#                     "name": "\u4f01\u4e1aVIP-\u5168\u7528\u9014-2"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u5b63-2"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u6708-2"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u5b63-2"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u6708-2"
#                 },
#                 {
#                     "name": "\u672a\u5145\u503c-3"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u6708-3"
#                 },
#                 {
#                     "name": "\u5546\u7528VIP\u5305\u5e74-3"
#                 },
#                 {
#                     "name": "\u666e\u901aVIP\u5305\u5b63-3"
#                 },
#                 {
#                     "name": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014-3"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u4f01\u4e1aVIP-\u5168\u7528\u9014",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 11
#                 },
#                 {
#                     "source": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 19
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5b63",
#                     "target": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5b63",
#                     "target": "\u5546\u7528VIP\u5305\u5e74-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5b63",
#                     "target": "\u666e\u901aVIP\u5305\u5e74-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5b63",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 24
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5e74",
#                     "target": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5e74",
#                     "target": "\u5546\u7528VIP\u5305\u5e74-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5e74",
#                     "target": "\u666e\u901aVIP\u5305\u5e74-2",
#                     "value": 2
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u5e74",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 52
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u4f01\u4e1aVIP-\u5168\u7528\u9014-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u5546\u7528VIP\u5305\u5b63-2",
#                     "value": 4
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u5546\u7528VIP\u5305\u5e74-2",
#                     "value": 3
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u5546\u7528VIP\u5305\u6708-2",
#                     "value": 8
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u666e\u901aVIP\u5305\u5b63-2",
#                     "value": 2
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u666e\u901aVIP\u5305\u5e74-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u666e\u901aVIP\u5305\u6708-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u5546\u7528VIP\u5305\u6708",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 103
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u5b63",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 23
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u5e74",
#                     "target": "\u5546\u7528VIP\u5305\u5b63-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u5e74",
#                     "target": "\u5546\u7528VIP\u5305\u5e74-2",
#                     "value": 3
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u5e74",
#                     "target": "\u5546\u7528VIP\u5305\u6708-2",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u5e74",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 48
#                 },
#                 {
#                     "source": "\u666e\u901aVIP\u5305\u6708",
#                     "target": "\u672a\u5145\u503c-2",
#                     "value": 28
#                 },
#                 {
#                     "source": "\u4f01\u4e1aVIP-\u5168\u7528\u9014-2",
#                     "target": "\u672a\u5145\u503c-3",
#                     "value": 1
#                 },
#                 {
#                     "source": "\u4f01\u4e1aVIP-\u7ebf\u4e0a\u7528\u9014-2",
#                     "target": "\u672a\u
